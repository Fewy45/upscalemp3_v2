# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewmcq/upscalemp3_v2/blob/main/upscale_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -r /content/drive/MyDrive/upscalemp3/upscalemp3_v2/requirements.txt

# %%
import sys
sys.path.append('/content/drive/MyDrive/upscalemp3/upscalemp3_v2/src')

# %%
import tensorflow as tf

tf.keras.backend.clear_session()

# Then set threading parameters globally
tf.config.threading.set_inter_op_parallelism_threads(2)
tf.config.threading.set_intra_op_parallelism_threads(2)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Pre-training

# %%
# !mkdir /content/data
# !gcloud storage cp -r gs://upscalemp3 /content/data

# %% [markdown]
# # Training

# %%
from train import train_model

model, history = train_model(tfrecords_dir="/content/data/upscalemp3", save_directory="/content/drive/MyDrive/upscalemp3")
# Out:
# Memory growth enabled for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Starting audio source separation pipeline...
# Creating TensorFlow dataset for training from TFRecords...
# Num records: 498
# Num val records: 49
# Num train records: 449
# Training dataset ready
# Training dataset created with 57600 examples
# Validation dataset created with 6400 examples
# Creating Wavelet U-Net model...
# Compiling model...
# Model: "wavelet_u_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ initial_conv (Conv1D)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ initial_norm                    │ ?                      │   0 (unbuilt) │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_1 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_1 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_1                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_2 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_2 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_2                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_3 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_3 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_3                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_4 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_4 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_4                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_5 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_5 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_5                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_6 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_6 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_6                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_7 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_7 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_7                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_8 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_8 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_8                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_9 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_9 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_9                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_10 (DownsamplingLayer) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_10 (DWTLayer)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_10                 │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_10 (IDWTLayer)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_10 (UpsamplingLayer) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_10              │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_9 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_9 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_9               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_2 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_8 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_8 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_8               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_7 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_7 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_7               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_6 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_6 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_6               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_5 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_5 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_5 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_5               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_6 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_4 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_4 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_4               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_7 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_3 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_3 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_3               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_2 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_2 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_2               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_9 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_1 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_1 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_1               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_10 (Sequential)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_11 (Sequential)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_conv (Conv1D)            │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model: "wavelet_u_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ initial_conv (Conv1D)           │ (16, 44100, 16)        │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ initial_norm                    │ (16, 44100, 16)        │            32 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_1 (DownsamplingLayer)  │ ?                      │         4,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_1 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_1                  │ ?                      │         9,952 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_2 (DownsamplingLayer)  │ ?                      │        16,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_2 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_2                  │ ?                      │        39,360 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_3 (DownsamplingLayer)  │ ?                      │        49,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_3 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_3                  │ ?                      │        88,224 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_4 (DownsamplingLayer)  │ ?                      │        98,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_4 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_4                  │ ?                      │       156,544 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_5 (DownsamplingLayer)  │ ?                      │       164,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_5 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_5                  │ ?                      │       244,320 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_6 (DownsamplingLayer)  │ ?                      │       246,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_6 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_6                  │ ?                      │       351,552 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_7 (DownsamplingLayer)  │ ?                      │       344,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_7 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_7                  │ ?                      │       478,240 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_8 (DownsamplingLayer)  │ ?                      │       459,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_8 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_8                  │ ?                      │       624,384 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_9 (DownsamplingLayer)  │ ?                      │       590,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_9 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_9                  │ ?                      │       789,984 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_10 (DownsamplingLayer) │ ?                      │       737,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_10 (DWTLayer)               │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_10                 │ ?                      │       975,040 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (16, 39, 176)          │       901,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_10 (IDWTLayer)             │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_10 (UpsamplingLayer) │ ?                      │        80,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_10              │ ?                      │        52,160 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (16, 82, 160)          │     1,229,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_9 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_9 (UpsamplingLayer)  │ ?                      │        66,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_9               │ ?                      │        42,336 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_2 (Sequential)       │ (16, 168, 144)         │       996,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_8 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_8 (UpsamplingLayer)  │ ?                      │        53,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_8               │ ?                      │        33,536 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (16, 340, 128)         │       787,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_7 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_7 (UpsamplingLayer)  │ ?                      │        42,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_7               │ ?                      │        25,760 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (16, 685, 112)         │       602,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_6 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_6 (UpsamplingLayer)  │ ?                      │        32,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_6               │ ?                      │        19,008 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_5 (Sequential)       │ (16, 1374, 96)         │       442,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_5 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_5 (UpsamplingLayer)  │ ?                      │        23,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_5               │ ?                      │        13,280 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_6 (Sequential)       │ (16, 2752, 80)         │       307,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_4 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_4 (UpsamplingLayer)  │ ?                      │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_4               │ ?                      │         8,576 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_7 (Sequential)       │ (16, 5509, 64)         │       196,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_3 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_3 (UpsamplingLayer)  │ ?                      │        10,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_3               │ ?                      │         4,896 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ (16, 11022, 48)        │       110,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_2 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_2 (UpsamplingLayer)  │ ?                      │         5,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_2               │ ?                      │         2,240 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_9 (Sequential)       │ (16, 22048, 32)        │        49,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_1 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_1 (UpsamplingLayer)  │ ?                      │         2,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_1               │ ?                      │           608 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_10 (Sequential)      │ (16, 44100, 16)        │        12,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_11 (Sequential)      │ (16, 44100, 16)        │         8,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_conv (Conv1D)            │ (16, 44100, 1)         │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,652,594 (48.27 MB)
#  Trainable params: 12,652,274 (48.26 MB)
#  Non-trainable params: 320 (1.25 KB)
# Setting up training callbacks...
# Training model for 100 epochs...
# Epoch 1/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0035 - mse: 0.0035
# Epoch 1: val_loss improved from inf to 0.00023, saving model to checkpoints/wavelet_unet_01_0.0002.keras
#
# Epoch 1: val_loss improved from inf to 0.00023, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_01_0.0002.keras
#
# Epoch 1: val_loss improved from inf to 0.00023, saving model to checkpoints/wavelet_unet_01_0.0002_weightsonly.weights.h5
#
# Epoch 1: val_loss improved from inf to 0.00023, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_01_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 6200s 1s/step - loss: 0.0035 - mse: 0.0035 - val_loss: 2.3267e-04 - val_mse: 2.3267e-04 - learning_rate: 0.0010
# Epoch 2/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 55:36 1s/step - loss: 2.3730e-04 - mse: 2.3730e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_loss did not improve from 0.00023
#
# Epoch 2: val_loss did not improve from 0.00023
#
# Epoch 2: val_loss did not improve from 0.00023
#
# Epoch 2: val_loss did not improve from 0.00023
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 1486s 413ms/step - loss: 2.3548e-04 - mse: 2.3548e-04 - val_loss: 2.5451e-04 - val_mse: 2.5451e-04 - learning_rate: 0.0010
# Epoch 3/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.0849e-04 - mse: 2.0849e-04
# Epoch 3: val_loss improved from 0.00023 to 0.00018, saving model to checkpoints/wavelet_unet_03_0.0002.keras
#
# Epoch 3: val_loss improved from 0.00023 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_03_0.0002.keras
#
# Epoch 3: val_loss improved from 0.00023 to 0.00018, saving model to checkpoints/wavelet_unet_03_0.0002_weightsonly.weights.h5
#
# Epoch 3: val_loss improved from 0.00023 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_03_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5072s 1s/step - loss: 2.0850e-04 - mse: 2.0850e-04 - val_loss: 1.8127e-04 - val_mse: 1.8127e-04 - learning_rate: 0.0010
# Epoch 4/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 16:02 343ms/step - loss: 1.8331e-04 - mse: 1.8331e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 4: val_loss did not improve from 0.00018
#
# Epoch 4: val_loss did not improve from 0.00018
#
# Epoch 4: val_loss did not improve from 0.00018
#
# Epoch 4: val_loss did not improve from 0.00018
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 816s 227ms/step - loss: 1.9674e-04 - mse: 1.9674e-04 - val_loss: 2.0604e-04 - val_mse: 2.0604e-04 - learning_rate: 0.0010
# Epoch 5/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.8694e-04 - mse: 1.8694e-04
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5062s 1s/step - loss: 1.8694e-04 - mse: 1.8694e-04 - val_loss: 1.9028e-04 - val_mse: 1.9028e-04 - learning_rate: 0.0010
# Epoch 6/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:51 340ms/step - loss: 1.8160e-04 - mse: 1.8160e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_06_0.0002.keras
#
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_06_0.0002.keras
#
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_06_0.0002_weightsonly.weights.h5
#
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_06_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 823s 228ms/step - loss: 1.8727e-04 - mse: 1.8727e-04 - val_loss: 1.7532e-04 - val_mse: 1.7532e-04 - learning_rate: 5.0000e-04
# Epoch 7/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.7028e-04 - mse: 1.7028e-04
# Epoch 7: val_loss improved from 0.00018 to 0.00016, saving model to checkpoints/wavelet_unet_07_0.0002.keras
#
# Epoch 7: val_loss improved from 0.00018 to 0.00016, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_07_0.0002.keras
#
# Epoch 7: val_loss improved from 0.00018 to 0.00016, saving model to checkpoints/wavelet_unet_07_0.0002_weightsonly.weights.h5
#
# Epoch 7: val_loss improved from 0.00018 to 0.00016, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_07_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5227s 1s/step - loss: 1.7028e-04 - mse: 1.7028e-04 - val_loss: 1.6441e-04 - val_mse: 1.6441e-04 - learning_rate: 5.0000e-04
# Epoch 8/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 16:46 359ms/step - loss: 1.7659e-04 - mse: 1.7659e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 8: val_loss did not improve from 0.00016
#
# Epoch 8: val_loss did not improve from 0.00016
#
# Epoch 8: val_loss did not improve from 0.00016
#
# Epoch 8: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 834s 232ms/step - loss: 1.7964e-04 - mse: 1.7964e-04 - val_loss: 1.7767e-04 - val_mse: 1.7767e-04 - learning_rate: 5.0000e-04
# Epoch 9/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6941e-04 - mse: 1.6941e-04
# Epoch 9: val_loss did not improve from 0.00016
#
# Epoch 9: val_loss did not improve from 0.00016
#
# Epoch 9: val_loss did not improve from 0.00016
#
# Epoch 9: val_loss did not improve from 0.00016
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5046s 1s/step - loss: 1.6942e-04 - mse: 1.6942e-04 - val_loss: 1.6625e-04 - val_mse: 1.6625e-04 - learning_rate: 5.0000e-04
# Epoch 10/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:50 339ms/step - loss: 1.7315e-04 - mse: 1.7315e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 10: val_loss did not improve from 0.00016
#
# Epoch 10: val_loss did not improve from 0.00016
#
# Epoch 10: val_loss did not improve from 0.00016
#
# Epoch 10: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 814s 226ms/step - loss: 1.7552e-04 - mse: 1.7552e-04 - val_loss: 1.6751e-04 - val_mse: 1.6751e-04 - learning_rate: 2.5000e-04
# Epoch 11/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6774e-04 - mse: 1.6774e-04
# Epoch 11: val_loss improved from 0.00016 to 0.00016, saving model to checkpoints/wavelet_unet_11_0.0002.keras
#
# Epoch 11: val_loss improved from 0.00016 to 0.00016, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_11_0.0002.keras
#
# Epoch 11: val_loss improved from 0.00016 to 0.00016, saving model to checkpoints/wavelet_unet_11_0.0002_weightsonly.weights.h5
#
# Epoch 11: val_loss improved from 0.00016 to 0.00016, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_11_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5056s 1s/step - loss: 1.6774e-04 - mse: 1.6774e-04 - val_loss: 1.6327e-04 - val_mse: 1.6327e-04 - learning_rate: 2.5000e-04
# Epoch 12/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:59 342ms/step - loss: 1.8072e-04 - mse: 1.8072e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 12: val_loss did not improve from 0.00016
#
# Epoch 12: val_loss did not improve from 0.00016
#
# Epoch 12: val_loss did not improve from 0.00016
#
# Epoch 12: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 815s 226ms/step - loss: 1.7703e-04 - mse: 1.7703e-04 - val_loss: 1.6912e-04 - val_mse: 1.6912e-04 - learning_rate: 2.5000e-04
# Epoch 13/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6457e-04 - mse: 1.6457e-04
# Epoch 13: val_loss did not improve from 0.00016
#
# Epoch 13: val_loss did not improve from 0.00016
#
# Epoch 13: val_loss did not improve from 0.00016
#
# Epoch 13: val_loss did not improve from 0.00016
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5045s 1s/step - loss: 1.6457e-04 - mse: 1.6457e-04 - val_loss: 1.7274e-04 - val_mse: 1.7274e-04 - learning_rate: 2.5000e-04
# Epoch 14/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:51 339ms/step - loss: 1.6877e-04 - mse: 1.6877e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 14: val_loss did not improve from 0.00016
#
# Epoch 14: val_loss did not improve from 0.00016
#
# Epoch 14: val_loss did not improve from 0.00016
#
# Epoch 14: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 816s 227ms/step - loss: 1.6667e-04 - mse: 1.6667e-04 - val_loss: 1.7259e-04 - val_mse: 1.7259e-04 - learning_rate: 1.2500e-04
# Epoch 15/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6447e-04 - mse: 1.6447e-04
# Epoch 15: val_loss did not improve from 0.00016
#
# Epoch 15: val_loss did not improve from 0.00016
#
# Epoch 15: val_loss did not improve from 0.00016
#
# Epoch 15: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5077s 1s/step - loss: 1.6447e-04 - mse: 1.6447e-04 - val_loss: 1.6996e-04 - val_mse: 1.6996e-04 - learning_rate: 1.2500e-04
# Epoch 16/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 16:06 345ms/step - loss: 1.7574e-04 - mse: 1.7574e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 16: val_loss did not improve from 0.00016
#
# Epoch 16: val_loss did not improve from 0.00016
#
# Epoch 16: val_loss did not improve from 0.00016
#
# Epoch 16: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 821s 228ms/step - loss: 1.7582e-04 - mse: 1.7582e-04 - val_loss: 1.7162e-04 - val_mse: 1.7162e-04 - learning_rate: 1.2500e-04
# Epoch 17/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6566e-04 - mse: 1.6566e-04
# Epoch 17: val_loss did not improve from 0.00016
#
# Epoch 17: val_loss did not improve from 0.00016
#
# Epoch 17: val_loss did not improve from 0.00016
#
# Epoch 17: val_loss did not improve from 0.00016
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5063s 1s/step - loss: 1.6566e-04 - mse: 1.6566e-04 - val_loss: 1.7438e-04 - val_mse: 1.7438e-04 - learning_rate: 1.2500e-04
# Epoch 18/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 16:12 347ms/step - loss: 1.8312e-04 - mse: 1.8312e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 18: val_loss did not improve from 0.00016
#
# Epoch 18: val_loss did not improve from 0.00016
#
# Epoch 18: val_loss did not improve from 0.00016
#
# Epoch 18: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 820s 228ms/step - loss: 1.7446e-04 - mse: 1.7446e-04 - val_loss: 1.7197e-04 - val_mse: 1.7197e-04 - learning_rate: 6.2500e-05
# Epoch 19/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6470e-04 - mse: 1.6470e-04
# Epoch 19: val_loss did not improve from 0.00016
#
# Epoch 19: val_loss did not improve from 0.00016
#
# Epoch 19: val_loss did not improve from 0.00016
#
# Epoch 19: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5060s 1s/step - loss: 1.6470e-04 - mse: 1.6470e-04 - val_loss: 1.7239e-04 - val_mse: 1.7239e-04 - learning_rate: 6.2500e-05
# Epoch 20/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:57 341ms/step - loss: 1.7432e-04 - mse: 1.7432e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 20: val_loss improved from 0.00016 to 0.00016, saving model to checkpoints/wavelet_unet_20_0.0002.keras
#
# Epoch 20: val_loss improved from 0.00016 to 0.00016, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_20_0.0002.keras
#
# Epoch 20: val_loss improved from 0.00016 to 0.00016, saving model to checkpoints/wavelet_unet_20_0.0002_weightsonly.weights.h5
#
# Epoch 20: val_loss improved from 0.00016 to 0.00016, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_20_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 822s 228ms/step - loss: 1.7728e-04 - mse: 1.7728e-04 - val_loss: 1.6321e-04 - val_mse: 1.6321e-04 - learning_rate: 6.2500e-05
# Epoch 21/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6259e-04 - mse: 1.6259e-04
# Epoch 21: val_loss did not improve from 0.00016
#
# Epoch 21: val_loss did not improve from 0.00016
#
# Epoch 21: val_loss did not improve from 0.00016
#
# Epoch 21: val_loss did not improve from 0.00016
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5073s 1s/step - loss: 1.6260e-04 - mse: 1.6260e-04 - val_loss: 1.7496e-04 - val_mse: 1.7496e-04 - learning_rate: 6.2500e-05
# Epoch 22/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 16:01 343ms/step - loss: 1.7707e-04 - mse: 1.7707e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 22: val_loss did not improve from 0.00016
#
# Epoch 22: val_loss did not improve from 0.00016
#
# Epoch 22: val_loss did not improve from 0.00016
#
# Epoch 22: val_loss did not improve from 0.00016
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 815s 226ms/step - loss: 1.7075e-04 - mse: 1.7074e-04 - val_loss: 1.6650e-04 - val_mse: 1.6650e-04 - learning_rate: 3.1250e-05
# Epoch 23/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.5844e-04 - mse: 1.5844e-04
# Epoch 23: val_loss improved from 0.00016 to 0.00015, saving model to checkpoints/wavelet_unet_23_0.0002.keras
#
# Epoch 23: val_loss improved from 0.00016 to 0.00015, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_23_0.0002.keras
#
# Epoch 23: val_loss improved from 0.00016 to 0.00015, saving model to checkpoints/wavelet_unet_23_0.0002_weightsonly.weights.h5
#
# Epoch 23: val_loss improved from 0.00016 to 0.00015, saving model to /content/drive/MyDrive/upscalemp3/wavelet_unet_23_0.0002_weightsonly.weights.h5
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5073s 1s/step - loss: 1.5844e-04 - mse: 1.5844e-04 - val_loss: 1.5190e-04 - val_mse: 1.5190e-04 - learning_rate: 3.1250e-05
# Epoch 24/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 16:04 344ms/step - loss: 1.8208e-04 - mse: 1.8208e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 24: val_loss did not improve from 0.00015
#
# Epoch 24: val_loss did not improve from 0.00015
#
# Epoch 24: val_loss did not improve from 0.00015
#
# Epoch 24: val_loss did not improve from 0.00015
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 822s 228ms/step - loss: 1.7604e-04 - mse: 1.7604e-04 - val_loss: 1.6566e-04 - val_mse: 1.6566e-04 - learning_rate: 3.1250e-05
# Epoch 25/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6479e-04 - mse: 1.6479e-04
# Epoch 25: val_loss did not improve from 0.00015
#
# Epoch 25: val_loss did not improve from 0.00015
#
# Epoch 25: val_loss did not improve from 0.00015
#
# Epoch 25: val_loss did not improve from 0.00015
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5053s 1s/step - loss: 1.6479e-04 - mse: 1.6479e-04 - val_loss: 1.7502e-04 - val_mse: 1.7502e-04 - learning_rate: 3.1250e-05
# Epoch 26/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:49 338ms/step - loss: 1.7161e-04 - mse: 1.7161e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 26: val_loss did not improve from 0.00015
#
# Epoch 26: val_loss did not improve from 0.00015
#
# Epoch 26: val_loss did not improve from 0.00015
#
# Epoch 26: val_loss did not improve from 0.00015
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 808s 224ms/step - loss: 1.7005e-04 - mse: 1.7005e-04 - val_loss: 1.6731e-04 - val_mse: 1.6731e-04 - learning_rate: 1.5625e-05
# Epoch 27/100
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.5979e-04 - mse: 1.5979e-04
# Epoch 27: val_loss did not improve from 0.00015
#
# Epoch 27: val_loss did not improve from 0.00015
#
# Epoch 27: val_loss did not improve from 0.00015
#
# Epoch 27: val_loss did not improve from 0.00015
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 5040s 1s/step - loss: 1.5979e-04 - mse: 1.5979e-04 - val_loss: 1.7017e-04 - val_mse: 1.7017e-04 - learning_rate: 1.5625e-05
# Epoch 28/100
#  796/3600 ━━━━━━━━━━━━━━━━━━━━ 15:56 341ms/step - loss: 1.5372e-04 - mse: 1.5372e-04
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 28: val_loss did not improve from 0.00015
#
# Epoch 28: val_loss did not improve from 0.00015
#
# Epoch 28: val_loss did not improve from 0.00015
#
# Epoch 28: val_loss did not improve from 0.00015
# 3600/3600 ━━━━━━━━━━━━━━━━━━━━ 821s 228ms/step - loss: 1.5964e-04 - mse: 1.5964e-04 - val_loss: 1.7940e-04 - val_mse: 1.7940e-04 - learning_rate: 1.5625e-05
# Epoch 29/100

# %% [markdown]
# ##RETRAIN

# %%
from main import load_saved_model
from train import train_model
model = load_saved_model("/content/drive/MyDrive/upscalemp3", "wavelet_unet_23_0.0002")
model_retrain, history_retrain = train_model(tfrecords_dir="/content/data/upscalemp3", save_directory="/content/drive/MyDrive/upscalemp3/retrain", model=model, retrain=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Attempting to load model from /content/drive/MyDrive/upscalemp3
# Model: "wavelet_u_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ initial_conv (Conv1D)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ initial_norm                    │ ?                      │   0 (unbuilt) │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_1 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_1 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_1                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_2 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_2 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_2                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_3 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_3 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_3                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_4 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_4 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_4                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_5 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_5 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_5                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_6 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_6 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_6                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_7 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_7 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_7                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_8 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_8 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_8                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_9 (DownsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_9 (DWTLayer)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_9                  │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_10 (DownsamplingLayer) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_10 (DWTLayer)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_10                 │ ?                      │   0 (unbuilt) │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_10 (IDWTLayer)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_10 (UpsamplingLayer) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_10              │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_9 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_9 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_9               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_2 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_8 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_8 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_8               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_7 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_7 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_7               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_6 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_6 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_6               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_5 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_5 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_5 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_5               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_6 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_4 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_4 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_4               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_7 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_3 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_3 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_3               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_2 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_2 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_2               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_9 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_1 (IDWTLayer)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_1 (UpsamplingLayer)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_1               │ ?                      │   0 (unbuilt) │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_10 (Sequential)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_11 (Sequential)      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_conv (Conv1D)            │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 1038 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Error setting memory growth: Physical devices cannot be modified after being initialized
# Starting audio source separation pipeline...
# Creating TensorFlow dataset for training from TFRecords...
# Num records: 498
# Num val records: 49
# Num train records: 449
# Training dataset ready
# Training dataset created with 69120 examples
# Validation dataset created with 7680 examples
# Creating Wavelet U-Net model...
# Compiling model...
# Model: "wavelet_u_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ initial_conv (Conv1D)           │ (16, 44100, 16)        │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ initial_norm                    │ (16, 44100, 16)        │            32 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_1 (DownsamplingLayer)  │ ?                      │         4,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_1 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_1                  │ ?                      │         9,952 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_2 (DownsamplingLayer)  │ ?                      │        16,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_2 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_2                  │ ?                      │        39,360 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_3 (DownsamplingLayer)  │ ?                      │        49,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_3 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_3                  │ ?                      │        88,224 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_4 (DownsamplingLayer)  │ ?                      │        98,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_4 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_4                  │ ?                      │       156,544 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_5 (DownsamplingLayer)  │ ?                      │       164,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_5 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_5                  │ ?                      │       244,320 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_6 (DownsamplingLayer)  │ ?                      │       246,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_6 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_6                  │ ?                      │       351,552 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_7 (DownsamplingLayer)  │ ?                      │       344,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_7 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_7                  │ ?                      │       478,240 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_8 (DownsamplingLayer)  │ ?                      │       459,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_8 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_8                  │ ?                      │       624,384 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_9 (DownsamplingLayer)  │ ?                      │       590,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_9 (DWTLayer)                │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_9                  │ ?                      │       789,984 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ds_block_10 (DownsamplingLayer) │ ?                      │       737,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dwt_10 (DWTLayer)               │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ down_process_10                 │ ?                      │       975,040 │
# │ (UpsamplingLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (16, 39, 176)          │       901,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_10 (IDWTLayer)             │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_10 (UpsamplingLayer) │ ?                      │        80,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_10              │ ?                      │        52,160 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (16, 82, 160)          │     1,229,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_9 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_9 (UpsamplingLayer)  │ ?                      │        66,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_9               │ ?                      │        42,336 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_2 (Sequential)       │ (16, 168, 144)         │       996,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_8 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_8 (UpsamplingLayer)  │ ?                      │        53,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_8               │ ?                      │        33,536 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (16, 340, 128)         │       787,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_7 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_7 (UpsamplingLayer)  │ ?                      │        42,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_7               │ ?                      │        25,760 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (16, 685, 112)         │       602,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_6 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_6 (UpsamplingLayer)  │ ?                      │        32,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_6               │ ?                      │        19,008 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_5 (Sequential)       │ (16, 1374, 96)         │       442,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_5 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_5 (UpsamplingLayer)  │ ?                      │        23,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_5               │ ?                      │        13,280 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_6 (Sequential)       │ (16, 2752, 80)         │       307,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_4 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_4 (UpsamplingLayer)  │ ?                      │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_4               │ ?                      │         8,576 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_7 (Sequential)       │ (16, 5509, 64)         │       196,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_3 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_3 (UpsamplingLayer)  │ ?                      │        10,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_3               │ ?                      │         4,896 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_8 (Sequential)       │ (16, 11022, 48)        │       110,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_2 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_2 (UpsamplingLayer)  │ ?                      │         5,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_2               │ ?                      │         2,240 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_9 (Sequential)       │ (16, 22048, 32)        │        49,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ idwt_1 (IDWTLayer)              │ ?                      │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_process_1 (UpsamplingLayer)  │ ?                      │         2,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ skip_connection_1               │ ?                      │           608 │
# │ (GatedSkipConnection)           │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_10 (Sequential)      │ (16, 44100, 16)        │        12,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_11 (Sequential)      │ (16, 44100, 16)        │         8,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_conv (Conv1D)            │ (16, 44100, 1)         │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,652,594 (48.27 MB)
#  Trainable params: 12,652,274 (48.26 MB)
#  Non-trainable params: 320 (1.25 KB)
# Setting up training callbacks...
# Training model for 100 epochs...
# Epoch 1/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0148e-04 - mse: 1.0148e-04
# Epoch 1: val_loss improved from inf to 0.00019, saving model to checkpoints/wavelet_unet_01_0.0002.keras
#
# Epoch 1: val_loss improved from inf to 0.00019, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_01_0.0002.keras
#
# Epoch 1: val_loss improved from inf to 0.00019, saving model to checkpoints/wavelet_unet_01_0.0002_weightsonly.weights.h5
#
# Epoch 1: val_loss improved from inf to 0.00019, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_01_0.0002_weightsonly.weights.h5
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 7688s 1s/step - loss: 1.0148e-04 - mse: 1.0148e-04 - val_loss: 1.8603e-04 - val_mse: 1.8603e-04 - learning_rate: 1.0000e-04
# Epoch 2/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0135e-04 - mse: 1.0135e-04
# Epoch 2: val_loss improved from 0.00019 to 0.00018, saving model to checkpoints/wavelet_unet_02_0.0002.keras
#
# Epoch 2: val_loss improved from 0.00019 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_02_0.0002.keras
#
# Epoch 2: val_loss improved from 0.00019 to 0.00018, saving model to checkpoints/wavelet_unet_02_0.0002_weightsonly.weights.h5
#
# Epoch 2: val_loss improved from 0.00019 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_02_0.0002_weightsonly.weights.h5
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5872s 1s/step - loss: 1.0135e-04 - mse: 1.0135e-04 - val_loss: 1.8476e-04 - val_mse: 1.8476e-04 - learning_rate: 1.0000e-04
# Epoch 3/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0564e-04 - mse: 1.0564e-04
# Epoch 3: val_loss did not improve from 0.00018
#
# Epoch 3: val_loss did not improve from 0.00018
#
# Epoch 3: val_loss did not improve from 0.00018
#
# Epoch 3: val_loss did not improve from 0.00018
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5875s 1s/step - loss: 1.0564e-04 - mse: 1.0564e-04 - val_loss: 1.8622e-04 - val_mse: 1.8622e-04 - learning_rate: 1.0000e-04
# Epoch 4/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0201e-04 - mse: 1.0201e-04
# Epoch 4: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_04_0.0002.keras
#
# Epoch 4: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_04_0.0002.keras
#
# Epoch 4: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_04_0.0002_weightsonly.weights.h5
#
# Epoch 4: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_04_0.0002_weightsonly.weights.h5
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5892s 1s/step - loss: 1.0201e-04 - mse: 1.0201e-04 - val_loss: 1.8372e-04 - val_mse: 1.8372e-04 - learning_rate: 1.0000e-04
# Epoch 5/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0625e-04 - mse: 1.0625e-04
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: val_loss did not improve from 0.00018
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5881s 1s/step - loss: 1.0625e-04 - mse: 1.0625e-04 - val_loss: 1.8560e-04 - val_mse: 1.8560e-04 - learning_rate: 1.0000e-04
# Epoch 6/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 9.7947e-05 - mse: 9.7947e-05
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_06_0.0002.keras
#
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_06_0.0002.keras
#
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_06_0.0002_weightsonly.weights.h5
#
# Epoch 6: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_06_0.0002_weightsonly.weights.h5
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5907s 1s/step - loss: 9.7947e-05 - mse: 9.7947e-05 - val_loss: 1.8193e-04 - val_mse: 1.8193e-04 - learning_rate: 5.0000e-05
# Epoch 7/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 9.9089e-05 - mse: 9.9089e-05
# Epoch 7: val_loss did not improve from 0.00018
#
# Epoch 7: val_loss did not improve from 0.00018
#
# Epoch 7: val_loss did not improve from 0.00018
#
# Epoch 7: val_loss did not improve from 0.00018
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5898s 1s/step - loss: 9.9089e-05 - mse: 9.9089e-05 - val_loss: 1.8262e-04 - val_mse: 1.8262e-04 - learning_rate: 5.0000e-05
# Epoch 8/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0100e-04 - mse: 1.0100e-04
# Epoch 8: val_loss did not improve from 0.00018
#
# Epoch 8: val_loss did not improve from 0.00018
#
# Epoch 8: val_loss did not improve from 0.00018
#
# Epoch 8: val_loss did not improve from 0.00018
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5918s 1s/step - loss: 1.0100e-04 - mse: 1.0100e-04 - val_loss: 1.8252e-04 - val_mse: 1.8252e-04 - learning_rate: 5.0000e-05
# Epoch 9/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.0175e-04 - mse: 1.0175e-04
# Epoch 9: val_loss did not improve from 0.00018
#
# Epoch 9: val_loss did not improve from 0.00018
#
# Epoch 9: val_loss did not improve from 0.00018
#
# Epoch 9: val_loss did not improve from 0.00018
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5972s 1s/step - loss: 1.0175e-04 - mse: 1.0175e-04 - val_loss: 1.8601e-04 - val_mse: 1.8601e-04 - learning_rate: 5.0000e-05
# Epoch 10/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - loss: 9.7035e-05 - mse: 9.7035e-05
# Epoch 10: val_loss did not improve from 0.00018
#
# Epoch 10: val_loss did not improve from 0.00018
#
# Epoch 10: val_loss did not improve from 0.00018
#
# Epoch 10: val_loss did not improve from 0.00018
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 6085s 1s/step - loss: 9.7035e-05 - mse: 9.7035e-05 - val_loss: 1.8780e-04 - val_mse: 1.8780e-04 - learning_rate: 2.5000e-05
# Epoch 11/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - loss: 1.0392e-04 - mse: 1.0392e-04
# Epoch 11: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_11_0.0002.keras
#
# Epoch 11: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_11_0.0002.keras
#
# Epoch 11: val_loss improved from 0.00018 to 0.00018, saving model to checkpoints/wavelet_unet_11_0.0002_weightsonly.weights.h5
#
# Epoch 11: val_loss improved from 0.00018 to 0.00018, saving model to /content/drive/MyDrive/upscalemp3/retrain/wavelet_unet_11_0.0002_weightsonly.weights.h5
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5656s 1s/step - loss: 1.0392e-04 - mse: 1.0392e-04 - val_loss: 1.8137e-04 - val_mse: 1.8137e-04 - learning_rate: 2.5000e-05
# Epoch 12/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - loss: 1.0283e-04 - mse: 1.0283e-04
# Epoch 12: val_loss did not improve from 0.00018
#
# Epoch 12: val_loss did not improve from 0.00018
#
# Epoch 12: val_loss did not improve from 0.00018
#
# Epoch 12: val_loss did not improve from 0.00018
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5474s 1s/step - loss: 1.0283e-04 - mse: 1.0283e-04 - val_loss: 1.8152e-04 - val_mse: 1.8152e-04 - learning_rate: 2.5000e-05
# Epoch 13/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - loss: 9.5078e-05 - mse: 9.5078e-05
# Epoch 13: val_loss did not improve from 0.00018
#
# Epoch 13: val_loss did not improve from 0.00018
#
# Epoch 13: val_loss did not improve from 0.00018
#
# Epoch 13: val_loss did not improve from 0.00018
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5540s 1s/step - loss: 9.5079e-05 - mse: 9.5079e-05 - val_loss: 1.8203e-04 - val_mse: 1.8203e-04 - learning_rate: 2.5000e-05
# Epoch 14/100
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - loss: 1.0329e-04 - mse: 1.0329e-04
# Epoch 14: val_loss did not improve from 0.00018
#
# Epoch 14: val_loss did not improve from 0.00018
#
# Epoch 14: val_loss did not improve from 0.00018
#
# Epoch 14: val_loss did not improve from 0.00018
# 4320/4320 ━━━━━━━━━━━━━━━━━━━━ 5475s 1s/step - loss: 1.0329e-04 - mse: 1.0329e-04 - val_loss: 1.8220e-04 - val_mse: 1.8220e-04 - learning_rate: 1.2500e-05
# Epoch 15/100
# 2559/4320 ━━━━━━━━━━━━━━━━━━━━ 17:50 608ms/step - loss: 1.0357e-04 - mse: 1.0357e-04
